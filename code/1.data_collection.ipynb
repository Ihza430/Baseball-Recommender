# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ## Import Data for Player Names and ID's

# %%
player_id = pd.read_csv('../SFBB Player ID Map - PLAYERIDMAP.csv')

# %%
player_id.head()
# Out:
#     IDPLAYER     PLAYERNAME   BIRTHDATE FIRSTNAME LASTNAME TEAM   LG POS  \
# 0  aardsda01  David Aardsma  12/27/1981     David  Aardsma  NaN  NaN   P
# 1   abadfe01  Fernando Abad  12/17/1985  Fernando     Abad  BAL   AL   P
# 2  abbotco01    Cory Abbott   9/20/1995      Cory   Abbott  CHC   NL   P
# 3  abramcj01      CJ Abrams   10/3/2000        CJ   Abrams   SD   NL  SS
# 4  abreual01   Albert Abreu   9/26/1995    Albert    Abreu  NYY   AL   P
#
#   IDFANGRAPHS  FANGRAPHSNAME  ...  DRAFTKINGSNAME OTTONEUID    HQID  \
# 0        1902  David Aardsma  ...   David Aardsma    4362.0     NaN
# 1        4994  Fernando Abad  ...   Fernando Abad    7372.0  3556.0
# 2   sa3005305    Cory Abbott  ...             NaN       NaN  6286.0
# 3   sa3010152      CJ Abrams  ...             NaN       NaN     NaN
# 4       17485   Albert Abreu  ...             NaN       NaN  5762.0
#
#     RAZZBALLNAME FANTRAXID    FANTRAXNAME   ROTOWIRENAME ALLPOS  \
# 0  David Aardsma       NaN            NaN  David Aardsma      P
# 1  Fernando Abad   *01viz*  Fernando Abad  Fernando Abad      P
# 2    Cory Abbott   *04ef6*    Cory Abbott    Cory Abbott      P
# 3      CJ Abrams   *04qk8*      CJ Abrams      CJ Abrams     SS
# 4   Albert Abreu   *03xy4*   Albert Abreu   Albert Abreu      P
#
#     NFBCLASTFIRST ACTIVE
# 0  Aardsma, David      N
# 1  Abad, Fernando      Y
# 2    Abbott, Cory      Y
# 3      Abrams, CJ      Y
# 4   Abreu, Albert      Y
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Specify which Columns and Rows Needed

# %%
mlb_id = player_id[['MLBID', 'FIRSTNAME', 'LASTNAME','POS', 'ACTIVE']]

# %% [markdown]
# #### Only Want Active Players

# %%
active = mlb_id[mlb_id['ACTIVE'] == 'Y']

# %%
active = active[active['POS']!= 'P']

# %%
active.head()
# Out:
#        MLBID  FIRSTNAME LASTNAME POS ACTIVE
# 3   682928.0         CJ   Abrams  SS      Y
# 7   547989.0       Jose    Abreu  1B      Y
# 12  554429.0     Dustin   Ackley  1B      Y
# 13  660670.0     Ronald    Acuna  OF      Y
# 14  542436.0  Cristhian   Adames  2B      Y

# %%
active.isnull().sum()
# Out:
# MLBID        1
# FIRSTNAME    0
# LASTNAME     0
# POS          0
# ACTIVE       0
# dtype: int64

# %%
active = active.dropna()

# %% [markdown]
# #### Change ID to Integer

# %%
active['MLBID'] = active['MLBID'].astype(int)

# %% [markdown]
# ## Function for Collecting Stats from Baseballsavant.mlb.com

# %%
def get_stats(mlbid, first_name, last_name):
    """
    This function collects the gamelog stats of every 
    game for that season for the specified player from the arguments.
    
    Returns csv file named after the player of their stats to specified location.
    """
    
    #This is the url to the website
    base_url = 'https://baseballsavant.mlb.com/savant-player/'
    
    #This string will be used to specifiy the player
    player_name = first_name.lower() +'-'+last_name.lower()+str(mlbid)
    
    #Url for the page with the stats
    url = base_url + player_name + '?stats=gamelogs-r-hitting-mlb&season=2021'
    
    #Requests for the page
    res = requests.get(url)

    print(res.status_code, first_name, last_name)
    
    soup = BeautifulSoup(res.content, 'lxml')
    
    player_stats = []
    
    try:

        #Find the table with desired stats
        table = soup.find('div', {'id':['gamelogs-mlb']})

        #Finds all the columns needed
        for row in table.find('tbody').find_all('tr'):

            td_tags = row.find_all('td')
            for index, td in enumerate(td_tags):
                stats = {}
                stats['date'] = td_tags[0].text.strip()
                stats['PA'] = td_tags[3].text.strip()
                stats['AB'] = td_tags[4].text.strip()
                stats['R'] = td_tags[5].text.strip()
                stats['H'] = td_tags[6].text.strip()
                stats['2B'] = td_tags[7].text.strip()
                stats['3B'] = td_tags[8].text.strip()
                stats['HR'] = td_tags[9].text.strip()
                stats['RBI'] = td_tags[10].text.strip()
                stats['BB'] = td_tags[11].text.strip()
                stats['SO'] = td_tags[12].text.strip()
                stats['AVG'] = td_tags[16].text.strip()
                stats['OBP'] = td_tags[17].text.strip()
                stats['SLG'] = td_tags[18].text.strip()
                stats['OPS'] = td_tags[19].text.strip()

            #Appends the row of stats to the list
            player_stats.append(stats)

        #Creates data frame of all stats
        df = pd.DataFrame(player_stats)

        #Saves Dataframe to a file with player name
        df.to_csv(f'./datasets/{first_name}-{last_name}-{mlbid}.csv')

        time.sleep(1) #suspends execution for 1 second to prevent too many requests
        #inspired from https://realpython.com/python-sleep/
        
    except (AttributeError, IndexError):
        print("Minor League Player! or Shohei Ohtani")

# %% [markdown]
# ## Get Stats for All Active Players

# %%
for index, row in active.iterrows():
    
    mlbid = row['MLBID']
    first = row['FIRSTNAME']
    last = row['LASTNAME']
    pos = row['POS']

    get_stats(mlbid, first, last)
    
# Copied from https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
# Out:
# 200 CJ Abrams
# Minor League Player! or Shohei Ohtani
# 200 Jose Abreu
# 200 Dustin Ackley
# 200 Ronald Acuna
# 200 Cristhian Adames
# 200 Willy Adames
# 200 David Adams
# 200 Lane Adams
# 200 Matt Adams
# 200 Jim Adduci
# 200 Jo Adell
# 200 Ehire Adrianza
# 200 Jesus Aguilar
# 200 Nick Ahmed
# 200 Shogo Akiyama
# 200 Hanser Alberto
# 200 Ozzie Albies
# 200 Arismendy Alcantara
# 200 Jorge Alfaro
# 200 Anthony Alford
# 200 Austin Allen
# 200 Greg Allen
# 200 Abraham Almonte
# 200 Zoilo Almonte
# 200 Albert Almora
# 200 Pete Alonso
# 200 Yonder Alonso
# 200 Aaron Altherr
# 200 Jose Altuve
# 200 Pedro Alvarez
# 200 Yordan Alvarez
# 200 Alexi Amarista
# 200 Bryan Anderson
# 200 Brian Anderson
# 200 Lars Anderson
# 200 Tim Anderson
# 200 Robert Andino
# 200 John Andreoli
# 200 Elvis Andrus
# 200 Miguel Andujar
# 200 Dean Anna
# 200 Aristides Aquino
# 200 Jonathan Arauz
# 200 Francisco Arcia
# 200 Orlando Arcia
# 200 Oswaldo Arcia
# 200 Nolan Arenado
# 200 Randy Arozarena
# 200 Luis Arraez
# 200 Christian Arroyo
# 200 Humberto Arteaga
# 200 Cody Asche
# 200 Willians Astudillo
# 200 Carlos Asuaje
# 200 Tyler Austin
# 200 Xavier Avery
# 200 Alex Avila
# 200 Akil Baddoo
# 200 Harrison Bader
# 200 Javier Baez
# 200 Jett Bandy
# 200 Austin Barnes
# 200 Brandon Barnes
# 200 Darwin Barney
# 200 Tucker Barnhart
# 200 Franklin Barreto
# 200 Joey Bart
# 200 Jake Bauers
# 200 Rafael Bautista
# 200 Matt Beaty
# 200 Gordon Beckham
# 200 Tim Beckham
# 200 Seth Beer
# 200 Cody Bellinger
# 200 Josh Bell
# 200 Brandon Belt
# 200 Anthony Bemboom
# 200 Andrew Benintendi
# 200 Joe Benson
# 200 Jon Berti
# 200 Mookie Betts
# 200 Jeff Bianchi
# 200 Bo Bichette
# 200 Cavan Biggio
# 200 Greg Bird
# 200 Braden Bishop
# 200 Charlie Blackmon
# 200 Alex Blandino
# 200 Jabari Blash
# 200 J.J. Bleday
# Minor League Player! or Shohei Ohtani
# 200 Xander Bogaerts
# 200 Alec Bohm
# 200 Emilio Bonifacio
# 200 Jorge Bonifacio
# 200 Julio Borbon
# 200 David Bote
# 200 Peter Bourjos
# 200 Justin Bour
# 200 Bobby Bradley
# 200 Jackie Bradley Jr.
# 200 Michael Brantley
# 200 Rob Brantly
# 200 Ryan Braun
# 200 Alex Bregman
# 200 Jose Briceno
# 200 Reid Brignac
# 200 Lewis Brinson
# 200 Socrates Brito
# 200 Michael Brosseau
# 200 Domonic Brown
# 200 Gary Brown
# 200 Seth Brown
# 200 Trevor Brown
# 200 Keon Broxton
# 200 Jay Bruce
# 200 Jaycob Brugman
# 200 Vidal Brujan
# 200 Kris Bryant
# 200 Jake Burger
# 200 Billy Burns
# 200 Drew Butera
# 200 Billy Butler
# 200 Joey Butler
# 200 Byron Buxton
# 200 Asdrubal Cabrera
# 200 Melky Cabrera
# 200 Miguel Cabrera
# 200 Lorenzo Cain
# 200 Kole Calhoun
# 200 Willie Calhoun
# 200 Johan Camargo
# 200 Daz Cameron
# 200 Eric Campbell
# 200 Luis Campusano
# 200 Jeimer Candelario
# 200 Mark Canha
# 200 Robinson Cano
# 200 Russ Canzler
# 200 Victor Caratini
# 200 Adrian Cardenas
# 200 Stephen Cardullo
# 200 Dylan Carlson
# 200 Matt Carpenter
# 200 Ezequiel Carrera
# 200 Chris Carter
# 200 Curt Casali
# 200 Alex Castellanos
# 200 Nick Castellanos
# 200 Rusney Castillo
# 200 Welington Castillo
# 200 Harold Castro
# 200 Jason Castro
# 200 Starlin Castro
# 200 Willi Castro
# 200 Jake Cave
# 200 Garin Cecchini
# 200 Gavin Cecchini
# 200 Juan Centeno
# 200 Francisco Cervelli
# 200 Yoenis Cespedes
# 200 Adron Chambers
# 200 Yu-Cheng Chang
# 200 Matt Chapman
# 200 Michael Chavis
# 200 Robinson Chirinos
# 200 Lonnie Chisenhall
# 200 Jazz Chisholm
# 200 Michael Choice
# 200 Ji-Man Choi
# 200 Shin-Soo Choo
# 200 Pedro Ciriaco
# 200 Nick Ciuffo
# 200 Steve Clevenger
# 200 Jason Coats
# 200 Chris Coghlan
# 200 Dusty Coleman
# 200 Tyler Collins
# 200 Zack Collins
# 200 Christian Colon
# 200 Tyler Colvin
# 200 Michael Conforto
# 200 Hank Conger
# 200 Willson Contreras
# 200 William Contreras
# 200 David Cooper
# 200 Garrett Cooper
# 200 Franchy Cordero
# 200 Ryan Cordell
# 200 Allen Cordoba
# 200 Carlos Correa
# 200 Kaleb Cowart
# 200 Collin Cowgill
# 200 Zack Cox
# Minor League Player! or Shohei Ohtani
# 200 Zack Cozart
# 200 Dylan Cozens
# 200 Brandon Crawford
# 200 J.P. Crawford
# 200 C.J. Cron
# 200 Jake Cronenworth
# 200 Kevin Cron
# 200 Nelson Cruz
# 200 Oneil Cruz
# 200 Tony Cruz
# 200 Noel Cuevas
# 200 Charlie Culberson
# 200 Todd Cunningham
# 200 Cheslor Cuthbert
# 200 David Dahl
# 200 Bobby Dalbec
# 200 Jordan Danks
# 200 Chase d'Arnaud
# 200 Travis D'Arnaud
# 200 James Darnell
# 200 Matt Davidson
# 200 Chris Davis
# 200 Jaylin Davis
# 200 J.D. Davis
# 200 Jonathan Davis
# 200 Khris Davis
# 200 Yonathan Daza
# 200 Austin Dean
# 200 Jaff Decker
# 200 Ivan De Jesus
# 200 Paul DeJong
# 200 Nick Delmonico
# 200 Travis Demeritte
# 200 Matt den Dekker
# 200 Daniel Descalso
# 200 Delino Deshields Jr.
# 200 Ian Desmond
# 200 Rafael Devers
# 200 Blake Dewitt
# 200 Aledmys Diaz
# 200 Elias Diaz
# 200 Isan Diaz
# 200 Lewin Diaz
# 200 Yandy Diaz
# 200 Yusniel Diaz
# Minor League Player! or Shohei Ohtani
# 200 Alex Dickerson
# 200 Corey Dickerson
# 200 Derek Dietrich
# 200 Wilmer Difo
# 200 Nick Dini
# 200 Andy Dirks
# 200 Brandon Dixon
# 200 Matt Dominguez
# 200 Josh Donaldson
# 200 Jeter Downs
# Minor League Player! or Shohei Ohtani
# 200 Brian Dozier
# 200 Hunter Dozier
# 200 Brandon Drury
# 200 Mauricio Dubon
# 200 Lucas Duda
# 200 Matt Duffy
# 200 Steven Duggar
# 200 Jarren Duran
# 200 Adam Duvall
# 200 Jarrod Dyson
# 200 Adam Eaton
# 200 Tommy Edman
# 200 Jake Elmore
# 200 Edwin Encarnacion
# 200 Adam Engel
# 200 Phil Ervin
# 200 Alcides Escobar
# 200 Eduardo Escobar
# 200 Danny Espinosa
# 200 Santiago Espinal
# 200 Thairo Estrada
# 200 Phillip Evans
# 200 Luis Exposito
# 200 Kyle Farmer
# 200 Eric Farris
# 200 Taylor Featherston
# 200 Tim Federowicz
# 200 Jose Miguel Fernandez
# 200 Johnny Field
# 200 Derek Fisher
# 200 Ryan Flaherty
# 200 David Fletcher
# 200 Ramon Flores
# 200 Wilmer Flores
# 200 Pedro Florimon
# 200 Tyler Flowers
# 200 Mike Ford
# 200 Logan Forsythe
# 200 Dexter Fowler
# 200 Dustin Fowler
# 200 Lucius Fox
# Minor League Player! or Shohei Ohtani
# 200 Jake Fraley
# 200 Juan Francisco
# 200 Maikel Franco
# 200 Ty France
# 200 Wander Franco
# 200 Nick Franklin
# 200 Adam Frazier
# 200 Clint Frazier
# 200 Todd Frazier
# 200 Freddie Freeman
# 200 Mike Freeman
# 200 Tyler Freeman
# Minor League Player! or Shohei Ohtani
# 200 David Freitas
# 200 Josh Fuentes
# 200 Reymond Fuentes
# 200 Cam Gallagher
# 200 Isaac Galloway
# 200 Joey Gallo
# 200 Freddy Galvis
# 200 Ben Gamel
# 200 Mat Gamel
# 200 Adonis Garcia
# 200 Adolis Garcia
# 200 Anthony Garcia
# Minor League Player! or Shohei Ohtani
# 200 Aramis Garcia
# 200 Avisail Garcia
# 200 Greg Garcia
# 200 Jose Garcia
# 200 Leury Garcia
# 200 Luis Garcia
# 200 Robel Garcia
# 200 Willy Garcia
# 200 Brett Gardner
# 200 Kyle Garlick
# 200 Dustin Garneau
# 200 Mitch Garver
# 200 Evan Gattis
# 200 Scooter Gennett
# 200 Michael Gerber
# 200 Johnny Giavotella
# 200 Conor Gillaspie
# 200 Andres Gimenez
# 200 Caleb Gindl
# 200 Tyler Goeddel
# 200 Ryan Goins
# 200 Paul Goldschmidt
# 200 Yan Gomes
# 200 Carlos Gomez
# 200 Carlos Gonzalez
# 200 Erik Gonzalez
# 200 Marwin Gonzalez
# 200 Niko Goodrum
# 200 Brian Goodwin
# 200 Alex Gordon
# 200 Dee Strange-Gordon
# 200 Nick Gordon
# 200 Terrance Gore
# 200 Phil Gosselin
# 200 Lourdes Gurriel
# 200 Yulieski Gurriel
# 200 Yasmani Grandal
# 200 Zack Granite
# 200 Grant Green
# 200 Riley Greene
# Minor League Player! or Shohei Ohtani
# 200 Taylor Green
# 200 Didi Gregorius
# 200 Grayson Greiner
# 200 Randal Grichuk
# 200 Trent Grisham
# 200 Robbie Grossman
# 200 Alexander Guerrero
# 200 Vladimir Guerrero Jr.
# 200 Luis Guillorme
# 200 Kelvin Gutierrez
# 200 Brandon Guyer
# 200 Jesus Guzman
# 200 Ronald Guzman
# 200 Jedd Gyorko
# 200 Eric Haase
# 200 Sam Haggerty
# 200 Billy Hamilton
# 200 Garrett Hampson
# 200 Mitch Haniger
# 200 Alen Hanson
# 200 Ian Happ
# 200 Bryce Harper
# 200 Josh Harrison
# 200 Monte Harrison
# 200 Adam Haseley
# 200 Alexander Hassan
# 200 Reese Havens
# Minor League Player! or Shohei Ohtani
# 200 Ke'Bryan Hayes
# 200 Austin Hays
# 200 Jeremy Hazelbaker
# 200 Ryon Healy
# 200 Adeiny Hechavarria
# 200 Austin Hedges
# 200 Jonah Heim
# 200 Scott Heineman
# 200 Tyler Heineman
# 200 Chris Heisey
# 200 Guillermo Heredia
# 200 Michael Hermosillo
# 200 Cesar Hernandez
# 200 Enrique Hernandez
# 200 Gorkys Hernandez
# 200 Marco Hernandez
# 200 Teoscar Hernandez
# 200 Dilson Herrera
# 200 Elian Herrera
# 200 Odubel Herrera
# 200 Rosell Herrera
# 200 Chris Herrmann
# 200 Jason Heyward
# 200 Aaron Hicks
# 200 Brandon Hicks
# 200 John Hicks
# 200 Kyle Higashioka
# 200 Sam Hilliard
# 200 Steven Hill
# 200 Keston Hiura
# 200 Nico Hoerner
# 200 L.J. Hoes
# 200 Bryan Holaday
# 200 Kyle Holder
# Minor League Player! or Shohei Ohtani
# 200 Brock Holt
# 200 Rhys Hoskins
# 200 Eric Hosmer
# 200 Ryan Howard
# Minor League Player! or Shohei Ohtani
# 200 Jared Hoying
# 200 Sam Huff
# 200 Jae-gyun Hwang
# 200 Chris Iannetta
# 200 Jose Iglesias
# 200 Ender Inciarte
# 200 Jonathan India
# 200 Alex Jackson
# 200 Alex Jackson
# 200 Austin Jackson
# 200 Brett Jackson
# 200 Ryan Jackson
# 200 Travis Jankowski
# 200 Danny Jansen
# 200 Jon Jay
# 200 Ryan Jeffers
# 200 Desmond Jennings
# 200 A.J. Jimenez
# 200 Eloy Jimenez
# 200 Luis Jimenez
# 200 Connor Joe
# 200 Daniel Johnson
# 200 Micah Johnson
# 200 Adam Jones
# 200 Jahmai Jones
# 200 James Jones
# Minor League Player! or Shohei Ohtani
# 200 JaCoby Jones
# 200 Nolan Jones
# Minor League Player! or Shohei Ohtani
# 200 Ryder Jones
# 200 Caleb Joseph
# 200 Corban Joseph
# 200 Tommy Joseph
# 200 Matt Joyce
# 200 Aaron Judge
# 200 Josh Jung
# Minor League Player! or Shohei Ohtani
# 200 Ryan Kalish
# 200 Jung-Ho Kang
# 200 Jarred Kelenic
# 200 Carson Kelly
# 200 Ty Kelly
# 200 Matt Kemp
# 200 Tony Kemp
# 200 Howie Kendrick
# 200 Max Kepler
# 200 Carter Kieboom
# 200 Spencer Kieboom
# 200 Kevin Kiermaier
# 200 Ha-Seong Kim
# 200 Hyun-soo Kim
# 200 Isiah Kiner-Falefa
# 200 Scott Kingery
# 200 Jason Kipnis
# 200 Alex Kirilloff
# 200 Alejandro Kirk
# 200 Patrick Kivlehan
# 200 Andrew Knapp
# 200 Andrew Knizner
# 200 Pete Kozma
# 200 Kevin Kramer
# 200 Erik Kratz
# 200 Kyle Kubitza
# 200 Tyler Ladendorf
# 200 Juan Lagares
# 200 Brandon Laird
# 200 Junior Lake
# 200 Ryan LaMarre
# 200 Jacob Lamb
# 200 Trevor Larnach
# 200 Tommy La Stella
# 200 Ramon Laureano
# 200 Ryan Lavarnway
# 200 Brett Lawrie
# 200 Khalil Lee
# 200 DJ LeMahieu
# 200 Sandy Leon
# 200 Kyle Lewis
# 200 Royce Lewis
# Minor League Player! or Shohei Ohtani
# 200 Domingo Leyba
# 200 Alex Liddi
# 200 Francisco Lindor
# 200 Tzu-Wei Lin
# 200 Rymer Liriano
# 200 Tim Locastro
# 200 Steve Lombardozzi
# 200 Evan Longoria
# 200 Shed Long
# 200 Tim Lopes
# 200 Nicky Lopez
# 200 Rafael Lopez
# 200 David Lough
# 200 Brandon Lowe
# 200 Josh Lowe
# 200 Nate Lowe
# 200 Jed Lowrie
# 200 Jonathan Lucroy
# 200 Dawel Lugo
# 200 Jordan Luplow
# 200 Donald Lutz
# 200 Zach Lutz
# 200 Gavin Lux
# 200 Dixon Machado
# 200 Manny Machado
# 200 Vimael Machin
# 200 Nick Madrigal
# 200 Mikie Mahtook
# 200 Luke Maile
# 200 Kevin Maitan
# Minor League Player! or Shohei Ohtani
# 200 Martin Maldonado
# 200 Trey Mancini
# 200 Manuel Margot
# 200 Jake Marisnick
# 200 Nick Markakis
# 200 Jose Marmolejos
# 200 Chris Marrero
# 200 Deven Marrero
# 200 Brandon Marsh
# 200 Lou Marson
# 200 Jefry Marte
# 200 Ketel Marte
# 200 Starling Marte
# 200 Austin Martin
# Minor League Player! or Shohei Ohtani
# 200 Fernando Martinez
# 200 Jason Martin
# 200 J.D. Martinez
# 200 Jose Martinez
# 200 Leonys Martin
# 200 Luis Martinez
# 200 Nick Martini
# 200 Richie Martin
# 200 Russell Martin
# 200 Darin Mastroianni
# 200 Jorge Mateo
# 200 Jeff Mathis
# 200 Wyatt Mathisen
# 200 Nick Maton
# 200 Bruce Maxwell
# 200 Cameron Maybin
# 200 Jack Mayfield
# 200 Jacob May
# 200 Nomar Mazara
# 200 Ryan McBroom
# 200 James McCann
# 200 Chas McCormick
# 200 Andrew McCutchen
# 200 Chris Mcguiness
# 200 Reese McGuire
# 200 Michael McKenry
# 200 Billy McKinney
# 200 Zach McKinstry
# 200 Ryan McMahon
# 200 Jeff McNeil
# 200 Austin Meadows
# 200 Tommy Medica
# 200 Ernesto Mejia
# Minor League Player! or Shohei Ohtani
# 200 Francisco Mejia
# 200 Seth Mejias-Brean
# 200 Danny Mendick
# 200 Oscar Mercado
# 200 Jordy Mercer
# 200 Yermin Mercedes
# 200 Whit Merrifield
# 200 Melky Mesa
# 200 Victor Victor Mesa
# Minor League Player! or Shohei Ohtani
# 200 Devin Mesoraco
# 200 Brad Miller
# 200 Owen Miller
# 200 Yadier Molina
# 200 Yoan Moncada
# 200 Adalberto Mondesi
# 200 Mickey Moniak
# 200 Jesus Montero
# 200 Dylan Moore
# 200 Tyler Moore
# 200 Colin Moran
# 200 Brent Morel
# 200 Mitch Moreland
# 200 Max Moroff
# 200 Logan Morrison
# 200 Taylor Motter
# 200 Ryan Mountcastle
# 200 Mike Moustakas
# 200 Steven Moya
# 200 Cedric Mullins
# 200 Max Muncy
# 200 Yairo Munoz
# 200 Daniel Murphy
# 200 John Ryan Murphy
# 200 Sean Murphy
# 200 Tom Murphy
# 200 Wil Myers
# 200 Tyler Naquin
# 200 Omar Narvaez
# 200 Efren Navarro
# 200 Josh Naylor
# 200 Thomas Neal
# 200 Kristopher Negron
# 200 Chris Nelson
# 200 Sheldon Neuse
# 200 Kevin Newman
# 200 Gift Ngoepe
# 200 Tomas Nido
# 200 Brandon Nimmo
# 200 Austin Nola
# 200 Jake Noll
# 200 Derek Norris
# 200 Jacob Nottingham
# 200 Dom Nunez
# 200 Eduardo Nunez
# 200 Renato Nunez
# 200 Peter O'Brien
# 200 Rougned Odor
# 200 Brian O'Grady
# 200 Ryan O'Hearn
# 200 Shohei Ohtani
# Minor League Player! or Shohei Ohtani
# 200 Edward Olivares
# 200 Jared Oliva
# 200 Hector Olivera
# 200 Matt Olson
# 200 Mike Olt
# 200 Shawn O'Malley
# 200 Tyler O'Neill
# 200 Paulo Orlando
# 200 Rafael Ortega
# 200 Jose Osuna
# 200 Chris Owings
# 200 Marcell Ozuna
# 200 Cristian Pache
# 200 Jordan Pacheco
# 200 Daniel Palka
# 200 Joe Panik
# 200 Isaac Paredes
# 200 Jimmy Paredes
# 200 Byung-ho Park
# 200 Jarrett Parker
# 200 Kyle Parker
# 200 Chris Parmelee
# 200 Gerardo Parra
# 200 Tyler Pastornicky
# 200 Dorssys Paulino
# Minor League Player! or Shohei Ohtani
# 200 Ben Paulsen
# 200 Xavier Paul
# 200 Mark Payton
# 200 Joc Pederson
# 200 Carlos Peguero
# 200 Francisco Peguero
# 200 Francisco Pena
# 200 Ramiro Pena
# 200 Hunter Pence
# 200 David Peralta
# 200 Jose Peraza
# 200 Carlos Perez
# 200 Delvin Perez
# Minor League Player! or Shohei Ohtani
# 200 Eury Perez
# 200 Hernan Perez
# 200 Michael Perez
# 200 Roberto Perez
# 200 Salvador Perez
# 200 Cam Perkins
# 200 Bryan Petersen
# 200 D.J. Peterson
# Minor League Player! or Shohei Ohtani
# 200 Dustin Peterson
# 200 Jace Peterson
# 200 Shane Peterson
# 200 Tommy Pham
# 200 Josh Phegley
# 200 Cord Phelps
# 200 Brett Phillips
# 200 Denis Phipps
# 200 Kevin Pillar
# 200 Manny Pina
# 200 Chad Pinder
# 200 Josmil Pinto
# 200 Jose Pirela
# 200 Stephen Piscotty
# 200 Kevin Plawecki
# 200 Trevor Plouffe
# 200 Gregory Polanco
# 200 Jorge Polanco
# 200 A.J. Pollock
# 200 Dalton Pompey
# 200 Buster Posey
# 200 Boog Powell
# 200 Alex Presley
# 200 Josh Prince
# 200 Jurickson Profar
# 200 Cesar Puello
# 200 Yasiel Puig
# 200 Albert Pujols
# 200 Roman Quinn
# 200 Cal Raleigh
# 200 Harold Ramirez
# 200 Jose Ramirez
# 200 Heliot Ramos
# Minor League Player! or Shohei Ohtani
# 200 Wilson Ramos
# 200 Rangel Ravelo
# 200 Corey Ray
# 200 J.T. Realmuto
# 200 Josh Reddick
# 200 A.J. Reed
# 200 Michael Reed
# 200 Robert Refsnyder
# 200 Anthony Rendon
# 200 Hunter Renfroe
# 200 Luis Rengifo
# 200 Ben Revere
# 200 Franmil Reyes
# 200 Jomar Reyes
# Minor League Player! or Shohei Ohtani
# 200 Pablo Reyes
# 200 Victor Reyes
# 200 Bryan Reynolds
# 200 Matt Reynolds
# 200 Joey Rickard
# 200 J.T. Riddle
# 200 Austin Riley
# 200 Edwin Rios
# 200 Rene Rivera
# 200 T.J. Rivera
# 200 Yadiel Rivera
# 200 Anthony Rizzo
# 200 Daniel Robertson
# 200 Daniel Robertson
# 200 Luis Robert
# 200 Clint Robinson
# 200 Drew Robinson
# 200 Kristian Robinson
# Minor League Player! or Shohei Ohtani
# 200 Trayvon Robinson
# 200 Victor Robles
# 200 Brendan Rodgers
# 200 Henry Rodriguez
# 200 Julio Rodriguez
# Minor League Player! or Shohei Ohtani
# 200 Ronny Rodrigues
# 200 Sean Rodriguez
# 200 Jason Rogers
# 200 Jake Rogers
# 200 Josh Rojas
# 200 Miguel Rojas
# 200 Stefen Romero
# 200 Andrew Romine
# 200 Austin Romine
# 200 Jose Rondon
# 200 Brent Rooker
# 200 Amed Rosario
# 200 Eddie Rosario
# 200 Wilin Rosario
# 200 Ryan Rua
# 200 Darin Ruf
# 200 Keibert Ruiz
# 200 Rio Ruiz
# 200 Cameron Rupp
# 200 Addison Russell
# 200 Blake Rutherford
# Minor League Player! or Shohei Ohtani
# 200 Josh Rutledge
# 200 Adley Rutschman
# Minor League Player! or Shohei Ohtani
# 200 Tyler Saladino
# 200 Adrian Sanchez
# 200 Yolmer Sanchez
# 200 Gary Sanchez
# 200 Hector Sanchez
# 200 Jesus Sanchez
# 200 Pablo Sandoval
# 200 Jerry Sands
# 200 Miguel Sano
# 200 Anthony Santander
# 200 Carlos Santana
# 200 Danny Santana
# 200 Domingo Santana
# 200 Dave Sappelt
# 200 Luis Sardinas
# 200 Josh Satin
# 200 Michael Saunders
# 200 Logan Schafer
# 200 Scott Schebler
# 200 Ryan Schimpf
# 200 Jonathan Schoop
# 200 Max Schrock
# 200 Kyle Schwarber
# 200 Corey Seager
# 200 Kyle Seager
# 200 Jean Segura
# 200 Marcus Semien
# 200 Nick Senzel
# 200 Pedro Severino
# 200 Richie Shaffer
# 200 Chris Shaw
# 200 Travis Shaw
# 200 J.B. Shuck
# 200 Magneuris Sierra
# 200 Moises Sierra
# 200 Andrelton Simmons
# 200 Jonathan Singleton
# 200 Chance Sisco
# 200 Scott Sizemore
# 200 Kyle Skipworth
# 200 Matt Skole
# 200 Austin Slater
# 200 Dominic Smith
# 200 Dwight Smith Jr.
# 200 Kevan Smith
# 200 Mallex Smith
# 200 Pavin Smith
# 200 Will Smith
# 200 Justin Smoak
# 200 Jake Smolinski
# 200 Travis Snider
# 200 Brandon Snyder
# 200 Eric Sogard
# 200 Nick Solak
# 200 Donovan Solano
# 200 Yangervis Solarte
# 200 Jorge Soler
# 200 Ali Solis
# 200 Edmundo Sosa
# 200 Juan Soto
# 200 Steven Souza
# 200 Cory Spangenberg
# 200 George Springer
# 200 Jacob Stallings
# 200 Eric Stamets
# 200 Giancarlo Stanton
# 200 Bubba Starling
# 200 Brock Stassi
# 200 Max Stassi
# 200 Tyler Stephenson
# 200 Andrew Stevenson
# 200 Christin Stewart
# 200 D.J. Stewart
# 200 Ian Stewart
# 200 Trevor Story
# 200 Myles Straw
# 200 Garrett Stubbs
# 200 Eugenio Suarez
# 200 Jesus Sucre
# 200 Andrew Susac
# 200 Kurt Suzuki
# 200 Dansby Swanson
# 200 Darnell Sweeney
# 200 Ryan Sweeney
# 200 Blake Swihart
# 200 Matt Szczur
# 200 Jose Tabata
# 200 Raimel Tapia
# 200 Fernando Tatis Jr.
# 200 Mike Tauchman
# 200 Leody Taveras
# 200 Beau Taylor
# 200 Chris Taylor
# 200 Michael Taylor
# 200 Tyrone Taylor
# 200 Ruben Tejada
# 200 Anderson Tejeda
# 200 Blake Tekotte
# 200 Tomas Telis
# 200 Rowdy Tellez
# 200 Matt Thaiss
# 200 Eric Thames
# 200 Josh Thole
# 200 Lane Thomas
# 200 Trayce Thompson
# 200 Charlie Tilson
# 200 Carlos Tocci
# 200 Andrew Toles
# 200 Yasmany Tomas
# 200 Ka'ai Tom
# 200 Kelby Tomlinson
# 200 Spencer Torkelson
# Minor League Player! or Shohei Ohtani
# 200 Abraham Toro
# 200 Gleyber Torres
# 200 Luis Torrens
# 200 Ronald Torreyes
# 200 Wilfredo Tovar
# 200 Taylor Trammell
# 200 Devon Travis
# 200 Sam Travis
# 200 Jose Trevino
# 200 Carlos Triunfel
# 200 Chadwick Tromp
# 200 Mike Trout
# 200 Mark Trumbo
# 200 Yoshitomo Tsutsugo
# 200 Cole Tucker
# 200 Kyle Tucker
# 200 Preston Tucker
# 200 Justin Turner
# 200 Trea Turner
# 200 Melvin Upton
# 200 Justin Upton
# 200 Richard Urena
# 200 Luis Urias
# 200 Henry Urrutia
# 200 Giovanny Urshela
# 200 Pat Valaika
# 200 Luis Valbuena
# 200 Jordany Valdespin
# 200 Breyvic Valera
# 200 Josh VanMeter
# 200 Scott Van Slyke
# 200 Ildemaro Vargas
# 200 Kennys Vargas
# 200 Daulton Varsho
# 200 Andrew Vaughn
# 200 Christian Vazquez
# 200 Andrew Velazquez
# 200 Alex Verdugo
# 200 Dayan Viciedo
# 200 Christian Villanueva
# 200 Jonathan Villar
# 200 Meibrys Viloria
# 200 Josh Vitters
# 200 Dan Vogelbach
# 200 Stephen Vogt
# 200 Luke Voit
# 200 Joey Votto
# 200 LaMonte Wade
# 200 Tyler Wade
# 200 Christian Walker
# 200 Neil Walker
# 200 Brett Wallace
# 200 Chad Wallach
# 200 Forrest Wall
# Minor League Player! or Shohei Ohtani
# 200 Taylor Walls
# 200 Colin Walsh
# 200 Jared Walsh
# 200 Zach Walters
# 200 Drew Ward
# Minor League Player! or Shohei Ohtani
# 200 Taylor Ward
# 200 Drew Waters
# Minor League Player! or Shohei Ohtani
# 200 Jemile Weeks
# 200 Colton Welker
# 200 Joey Wendle
# 200 Ryan Wheeler
# 200 Evan White
# 200 Tyler White
# 200 Matt Wieters
# 200 Steve Wilkerson
# 200 Justin Williams
# 200 Mason Williams
# 200 Mac Williamson
# 200 Nick Williams
# 200 Jesse Winker
# 200 Patrick Wisdom
# 200 Bobby Witt Jr.
# Minor League Player! or Shohei Ohtani
# 200 Tony Wolters
# 200 Kolten Wong
# 200 Brandon Wood
# 200 Danny Worth
# 200 Austin Wynns
# 200 Mike Yastrzemski
# 200 Christian Yelich
# 200 Delmon Young
# 200 Eric Young Jr.
# 200 Mark Zagunis
# 200 Bradley Zimmer
# 200 Ryan Zimmerman
# 200 Mike Zunino
# 200 Yadiel Hernandez
# 200 John Nogowski
# 200 Bryan De La Cruz
# 200 Andy Ibanez
# 200 DJ Peters
# 200 Drew Ellis
# 200 Stuart Fairchild
# 200 Ramon Urias
# 200 Seby Zavala
# 200 Yonny Hernandez
# 200 Jake Meyers
# 200 Curtis Terry
# 200 Hoy Park
# 200 Rodolfo Castro
# 200 Jason Vosler
# 200 Derek Hill
# 200 Gavin Sheets
# 200 Eli White
# 200 Frank Schwindel

# %%
active.shape
# Out:
# (992, 5)
