# %%
pip install MLB-StatsAPI
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsapi
import pandas as pd

# %%
people = statsapi.get('sports_players', {'season': 2021})['people']

# %%
person_id = [person['id'] for person in people]

# %%
stats = [statsapi.player_stats(person, 'hitting', 'season') for person in person_id]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-3ede16aa427e> in <module>
# ----> 1 stats = [statsapi.player_stats(person, 'hitting', 'season') for person in person_id]
#
# <ipython-input-106-3ede16aa427e> in <listcomp>(.0)
# ----> 1 stats = [statsapi.player_stats(person, 'hitting', 'season') for person in person_id]
#
# ~/opt/anaconda3/envs/dsi/lib/python3.8/site-packages/statsapi/__init__.py in player_stats(personId, group, type)
#    1083         stats += ' "{nickname}"'.format(**player)
#    1084
# -> 1085     stats += " {last_name}, {position} ({mlb_debut:.4}-".format(**player)
#    1086     if not player["active"]:
#    1087         stats += "{last_played:.4}".format(**player)
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
# Out:
# ['Jose "Mal Tiempo" Abreu, 1B (2014-)\n\nSeason Hitting\ngamesPlayed: 152\ngroundOuts: 156\nairOuts: 129\nruns: 86\ndoubles: 30\ntriples: 2\nhomeRuns: 30\nstrikeOuts: 143\nbaseOnBalls: 61\nintentionalWalks: 3\nhits: 148\nhitByPitch: 22\navg: .261\natBats: 566\nobp: .351\nslg: .481\nops: .831\ncaughtStealing: 0\nstolenBases: 1\nstolenBasePercentage: 1.000\ngroundIntoDoublePlay: 28\nnumberOfPitches: 2606\nplateAppearances: 659\ntotalBases: 272\nrbi: 117\nleftOnBase: 249\nsacBunts: 0\nsacFlies: 10\nbabip: .293\ngroundOutsToAirouts: 1.21\ncatchersInterference: 0\natBatsPerHomeRun: 18.87\n\n',
# ...

# %%
df
# Out:
#                                                       0
# 0     Jose "Mal Tiempo" Abreu, 1B (2014-)\n\nSeason ...
# 1     Ronald "El De La Sabana" Acuna, RF (2018-)\n\n...
# 2     Jason Adam, P (2018-)\n\nSeason Hitting\ngames...
# 3     Willy "The Kid" Adames, SS (2018-)\n\nSeason H...
# 4     Austin "A2" Adams, P (2017-)\n\nSeason Hitting...
# ...                                                 ...
# 1374  Mike "Z" Zunino, C (2013-)\n\nSeason Hitting\n...
# 1375           Chase "Cheetah" d'Arnaud, 3B (2011-)\n\n
# 1376  Travis "Little d'" d'Arnaud, C (2013-)\n\nSeas...
# 1377  Jacob "Jake" deGrom, P (2014-)\n\nSeason Hitti...
# 1378                 Matthew den Dekker, CF (2013-)\n\n
#
# [1379 rows x 1 columns]
