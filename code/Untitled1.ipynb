# %%
import pandas as pd

# %%
df = pd.read_csv('../stats.csv').drop(['Unnamed: 19'], axis = 1)

# %%
df.head()
# Out:
#    last_name  first_name  player_id  year  b_ab  b_total_pa  b_total_hits  \
# 0    Cabrera      Miguel     408234  2021   472         526           121
# 1   Cruz Jr.      Nelson     443558  2021   513         584           136
# 2    Peralta       David     444482  2021   487         538           126
# 3   Blackmon     Charlie     453568  2021   514         582           139
# 4  McCutchen      Andrew     457705  2021   482         574           107
#
#    b_single  b_double  b_triple  b_home_run  b_strikeout  b_walk  b_k_percent  \
# 0        90        16         0          15          118      40         22.4
# 1        82        21         1          32          126      51         21.6
# 2        80        30         8           8           92      46         17.1
# 3        97        25         4          13           91      54         15.6
# 4        55        24         1          27          132      81         23.0
#
# ...

# %%
df.isnull().sum()
# Out:
# last_name         0
#  first_name       0
# player_id         0
# year              0
# b_ab              0
# b_total_pa        0
# b_total_hits      0
# b_single          0
# b_double          0
# b_triple          0
# b_home_run        0
# b_strikeout       0
# b_walk            0
# b_k_percent       0
# b_bb_percent      0
# batting_avg       0
# slg_percent       0
# b_hit_by_pitch    0
# r_run             0
# dtype: int64

# %%
players = df.groupby('player_id')

# %%
players.groups.keys()
# Out:
# dict_keys([120074, 134181, 136860, 150029, 400121, 400284, 405395, 408045, 408234, 408236, 408252, 408314, 425783, 425834, 425877, 429664, 429665, 430832, 430945, 431145, 434158, 434636, 434670, 434778, 435062, 435063, 435079, 435622, 443558, 444432, 444482, 444876, 445055, 445988, 446334, 446359, 448602, 448801, 450314, 451594, 452104, 452254, 452655, 452678, 453056, 453064, 453568, 453943, 455976, 456030, 456488, 456715, 456781, 457705, 457708, 457759, 457763, 457787, 457803, 458015, 458731, 459431, 459964, 460075, 460086, 461314, 462101, 466320, 467092, 467793, 471865, 474568, 474832, 474892, 475174, 475253, 475582, 476704, 488726, 488862, 489149, 493316, 493329, 493351, 500208, 500743, 500871, 500874, 501896, 501981, 502054, 502110, 502143, 502210, 502517, 502671, 503556, 514888, 514917, 516416, 516770, 516782, 518618, 518626, 518692, 518735, 518792, 518934, 518960, 519048, 519058, 519203, 519306, 519317, 519346, 519390, 520471, 521692, 523253, 527038, 541645, 542255, 542303, 542
# ...

# %%
players.get_group(572761)
# Out:
#      last_name  first_name  player_id  year  b_ab  b_total_pa  b_total_hits  \
# 217  Carpenter        Matt     572761  2018   564         677           145
# 526  Carpenter        Matt     572761  2016   473         566           128
# 651  Carpenter        Matt     572761  2017   497         622           120
#
#      b_single  b_double  b_triple  b_home_run  b_strikeout  b_walk  \
# 217        67        42         0          36          158     102
# 526        65        36         6          21          108      81
# 651        64        31         2          23          125     109
#
#      b_k_percent  b_bb_percent  batting_avg  slg_percent  b_hit_by_pitch  \
# 217         23.3          15.1        0.257        0.523               6
# 526         19.1          14.3        0.271        0.505               5
# 651         20.1          17.5        0.241        0.451               9
#
#      r_run
# 217    111
# 526     81
# 651     91
