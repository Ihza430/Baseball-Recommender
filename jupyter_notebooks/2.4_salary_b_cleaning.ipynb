# %% [markdown]
# # Batter Salary Data Cleaning
# ---
# This notebook aims to clean the historical data of stats and salaries acquired from SeanLahmen.com. The data for salaries is from 1985-2016.

# %% [markdown]
# ## Import Libraries
# ---

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Import Historical Salary Dataset
# ---

# %%
salary = pd.read_csv('../data/lahman_database/Salaries.csv')
salary.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %% [markdown]
# ## Import Historical Batting Stats
# ---

# %%
bat = pd.read_csv('../data/lahman_database/Batting.csv')
bat.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  3B  HR   RBI  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0   0   0   0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6   0   0  13.0
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4   5   0  19.0
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10   2   2  27.0
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11   3   0  16.0
#
#     SB   CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# 1  8.0  1.0   4  0.0  NaN  NaN NaN NaN   0.0
# 2  3.0  1.0   2  5.0  NaN  NaN NaN NaN   1.0
# 3  1.0  1.0   0  2.0  NaN  NaN NaN NaN   0.0
# 4  6.0  2.0   2  1.0  NaN  NaN NaN NaN   0.0

# %% [markdown]
# ### Only get stats after 1985
# *This is because salary dataset starts at 1985*

# %%
bat = bat[bat['yearID']>1985]
bat = bat[bat['AB']> 50]
bat.head()
# Out:
#         playerID  yearID  stint teamID lgID    G   AB   R   H  2B  3B  HR  \
# 63258  aguaylu01    1986      1    PHI   NL   62  133  17  28   6   1   4
# 63259  aguilri01    1986      1    NYN   NL   32   51   4   8   0   0   2
# 63261  aldremi01    1986      1    SFN   NL   84  216  27  54  18   3   2
# 63264  allanan01    1986      1    CLE   AL  101  293  30  66   7   3   1
# 63266  almonbi01    1986      1    PIT   NL  102  196  29  43   7   2   7
#
#         RBI    SB   CS  BB    SO  IBB  HBP    SH   SF  GIDP
# 63258  13.0   1.0  1.0   8  26.0  0.0  3.0   0.0  2.0   3.0
# 63259   6.0   0.0  0.0   3  12.0  0.0  0.0   3.0  0.0   0.0
# 63261  25.0   1.0  3.0  33  34.0  4.0  2.0   4.0  1.0   3.0
# 63264  29.0  10.0  1.0  14  36.0  0.0  1.0  11.0  4.0   7.0
# 63266  27.0  11.0  4.0  30  38.0  2.0  0.0   1.0  3.0   5.0

# %% [markdown]
# ### Create new column for batting average

# %%
bat['AVG'] = round((bat['H'] / bat['AB']), 3)
bat.head()
# Out:
#         playerID  yearID  stint teamID lgID    G   AB   R   H  2B  3B  HR  \
# 63258  aguaylu01    1986      1    PHI   NL   62  133  17  28   6   1   4
# 63259  aguilri01    1986      1    NYN   NL   32   51   4   8   0   0   2
# 63261  aldremi01    1986      1    SFN   NL   84  216  27  54  18   3   2
# 63264  allanan01    1986      1    CLE   AL  101  293  30  66   7   3   1
# 63266  almonbi01    1986      1    PIT   NL  102  196  29  43   7   2   7
#
#         RBI    SB   CS  BB    SO  IBB  HBP    SH   SF  GIDP    AVG
# 63258  13.0   1.0  1.0   8  26.0  0.0  3.0   0.0  2.0   3.0  0.211
# 63259   6.0   0.0  0.0   3  12.0  0.0  0.0   3.0  0.0   0.0  0.157
# 63261  25.0   1.0  3.0  33  34.0  4.0  2.0   4.0  1.0   3.0  0.250
# 63264  29.0  10.0  1.0  14  36.0  0.0  1.0  11.0  4.0   7.0  0.225
# 63266  27.0  11.0  4.0  30  38.0  2.0  0.0   1.0  3.0   5.0  0.219

# %% [markdown]
# ### Create new column for on-base percentage

# %%
numerator = bat['H'] + bat['BB'] + bat['HBP']
plate = bat['AB'] + bat['BB'] + bat['HBP'] + bat['SF']
bat['OBP'] = round((numerator / plate), 3)
bat.head()
# Out:
#         playerID  yearID  stint teamID lgID    G   AB   R   H  2B  3B  HR  \
# 63258  aguaylu01    1986      1    PHI   NL   62  133  17  28   6   1   4
# 63259  aguilri01    1986      1    NYN   NL   32   51   4   8   0   0   2
# 63261  aldremi01    1986      1    SFN   NL   84  216  27  54  18   3   2
# 63264  allanan01    1986      1    CLE   AL  101  293  30  66   7   3   1
# 63266  almonbi01    1986      1    PIT   NL  102  196  29  43   7   2   7
#
#         RBI    SB   CS  BB    SO  IBB  HBP    SH   SF  GIDP    AVG    OBP
# 63258  13.0   1.0  1.0   8  26.0  0.0  3.0   0.0  2.0   3.0  0.211  0.267
# 63259   6.0   0.0  0.0   3  12.0  0.0  0.0   3.0  0.0   0.0  0.157  0.204
# 63261  25.0   1.0  3.0  33  34.0  4.0  2.0   4.0  1.0   3.0  0.250  0.353
# 63264  29.0  10.0  1.0  14  36.0  0.0  1.0  11.0  4.0   7.0  0.225  0.260
# 63266  27.0  11.0  4.0  30  38.0  2.0  0.0   1.0  3.0   5.0  0.219  0.319

# %% [markdown]
# ### Create new column for slugging percentage

# %%
first = bat['H'] - (bat['2B'] + bat['3B'] + bat['HR'])

bat['SLG'] = round(((first + (2 * bat['2B']) + (3 * bat['3B']) + (4 * bat['HR'])) / bat['AB']), 3)

bat.head()
# Out:
#         playerID  yearID  stint teamID lgID    G   AB   R   H  2B  3B  HR  \
# 63258  aguaylu01    1986      1    PHI   NL   62  133  17  28   6   1   4
# 63259  aguilri01    1986      1    NYN   NL   32   51   4   8   0   0   2
# 63261  aldremi01    1986      1    SFN   NL   84  216  27  54  18   3   2
# 63264  allanan01    1986      1    CLE   AL  101  293  30  66   7   3   1
# 63266  almonbi01    1986      1    PIT   NL  102  196  29  43   7   2   7
#
#         RBI    SB   CS  BB    SO  IBB  HBP    SH   SF  GIDP    AVG    OBP  \
# 63258  13.0   1.0  1.0   8  26.0  0.0  3.0   0.0  2.0   3.0  0.211  0.267
# 63259   6.0   0.0  0.0   3  12.0  0.0  0.0   3.0  0.0   0.0  0.157  0.204
# 63261  25.0   1.0  3.0  33  34.0  4.0  2.0   4.0  1.0   3.0  0.250  0.353
# 63264  29.0  10.0  1.0  14  36.0  0.0  1.0  11.0  4.0   7.0  0.225  0.260
# 63266  27.0  11.0  4.0  30  38.0  2.0  0.0   1.0  3.0   5.0  0.219  0.319
#
#          SLG
# 63258  0.361
# 63259  0.275
# 63261  0.389
# 63264  0.280
# 63266  0.383

# %% [markdown]
# ### Create new column for on-base plus slugging percentage

# %%
bat['OPS'] = bat['OBP'] + bat['SLG']

bat.head()
# Out:
#         playerID  yearID  stint teamID lgID    G   AB   R   H  2B  3B  HR  \
# 63258  aguaylu01    1986      1    PHI   NL   62  133  17  28   6   1   4
# 63259  aguilri01    1986      1    NYN   NL   32   51   4   8   0   0   2
# 63261  aldremi01    1986      1    SFN   NL   84  216  27  54  18   3   2
# 63264  allanan01    1986      1    CLE   AL  101  293  30  66   7   3   1
# 63266  almonbi01    1986      1    PIT   NL  102  196  29  43   7   2   7
#
#         RBI    SB   CS  BB    SO  IBB  HBP    SH   SF  GIDP    AVG    OBP  \
# 63258  13.0   1.0  1.0   8  26.0  0.0  3.0   0.0  2.0   3.0  0.211  0.267
# 63259   6.0   0.0  0.0   3  12.0  0.0  0.0   3.0  0.0   0.0  0.157  0.204
# 63261  25.0   1.0  3.0  33  34.0  4.0  2.0   4.0  1.0   3.0  0.250  0.353
# 63264  29.0  10.0  1.0  14  36.0  0.0  1.0  11.0  4.0   7.0  0.225  0.260
# 63266  27.0  11.0  4.0  30  38.0  2.0  0.0   1.0  3.0   5.0  0.219  0.319
#
#          SLG    OPS
# 63258  0.361  0.628
# 63259  0.275  0.479
# 63261  0.389  0.742
# 63264  0.280  0.540
# 63266  0.383  0.702

# %% [markdown]
# ### Drop unwanted columns

# %%
bat.drop(columns = ['GIDP', 'IBB', 'stint', 'SB', 'HBP', 'SH', 'SF', 'CS'], inplace = True)

bat.head()
# Out:
#         playerID  yearID teamID lgID    G   AB   R   H  2B  3B  HR   RBI  BB  \
# 63258  aguaylu01    1986    PHI   NL   62  133  17  28   6   1   4  13.0   8
# 63259  aguilri01    1986    NYN   NL   32   51   4   8   0   0   2   6.0   3
# 63261  aldremi01    1986    SFN   NL   84  216  27  54  18   3   2  25.0  33
# 63264  allanan01    1986    CLE   AL  101  293  30  66   7   3   1  29.0  14
# 63266  almonbi01    1986    PIT   NL  102  196  29  43   7   2   7  27.0  30
#
#          SO    AVG    OBP    SLG    OPS
# 63258  26.0  0.211  0.267  0.361  0.628
# 63259  12.0  0.157  0.204  0.275  0.479
# 63261  34.0  0.250  0.353  0.389  0.742
# 63264  36.0  0.225  0.260  0.280  0.540
# 63266  38.0  0.219  0.319  0.383  0.702

# %% [markdown]
# ### Merge salary and batting dataset

# %%
df = bat.merge(salary, how = 'inner', left_on = ['playerID', 'yearID'], right_on = ['playerID', 'yearID'])
df.head()
# Out:
#     playerID  yearID teamID_x lgID_x    G   AB   R   H  2B  3B  HR   RBI  BB  \
# 0  aguaylu01    1986      PHI     NL   62  133  17  28   6   1   4  13.0   8
# 1  aguilri01    1986      NYN     NL   32   51   4   8   0   0   2   6.0   3
# 2  aldremi01    1986      SFN     NL   84  216  27  54  18   3   2  25.0  33
# 3  allanan01    1986      CLE     AL  101  293  30  66   7   3   1  29.0  14
# 4  almonbi01    1986      PIT     NL  102  196  29  43   7   2   7  27.0  30
#
#      SO    AVG    OBP    SLG    OPS teamID_y lgID_y  salary
# 0  26.0  0.211  0.267  0.361  0.628      PHI     NL  275000
# 1  12.0  0.157  0.204  0.275  0.479      NYN     NL  130000
# 2  34.0  0.250  0.353  0.389  0.742      SFN     NL   60000
# 3  36.0  0.225  0.260  0.280  0.540      CLE     AL   60000
# 4  38.0  0.219  0.319  0.383  0.702      PIT     NL  260000

# %% [markdown]
# ### Drop repeated columns from merge

# %%
df.drop(columns = ['teamID_y', 'lgID_y'], inplace = True)
df.head()
# Out:
#     playerID  yearID teamID_x lgID_x    G   AB   R   H  2B  3B  HR   RBI  BB  \
# 0  aguaylu01    1986      PHI     NL   62  133  17  28   6   1   4  13.0   8
# 1  aguilri01    1986      NYN     NL   32   51   4   8   0   0   2   6.0   3
# 2  aldremi01    1986      SFN     NL   84  216  27  54  18   3   2  25.0  33
# 3  allanan01    1986      CLE     AL  101  293  30  66   7   3   1  29.0  14
# 4  almonbi01    1986      PIT     NL  102  196  29  43   7   2   7  27.0  30
#
#      SO    AVG    OBP    SLG    OPS  salary
# 0  26.0  0.211  0.267  0.361  0.628  275000
# 1  12.0  0.157  0.204  0.275  0.479  130000
# 2  34.0  0.250  0.353  0.389  0.742   60000
# 3  36.0  0.225  0.260  0.280  0.540   60000
# 4  38.0  0.219  0.319  0.383  0.702  260000

# %%
df.isnull().sum()
# Out:
# playerID    0
# yearID      0
# teamID_x    0
# lgID_x      0
# G           0
# AB          0
# R           0
# H           0
# 2B          0
# 3B          0
# HR          0
# RBI         0
# BB          0
# SO          0
# AVG         0
# OBP         0
# SLG         0
# OPS         0
# salary      0
# dtype: int64

# %% [markdown]
# ### Save clean dataset

# %%
df.to_csv('../data/past_salaries_bat.csv')

# %% [markdown]
# ## Recap
# ---
# Merged and cleaned the dataset for use in the regression model. Added new columns to match the stats scrapped for batters.
