# %% [markdown]
# # Batter Recommender System
# ---
# Using Current stats, salaries, and clusters, a recommender system was built using cosine distances.

# %% [markdown]
# ## Import Libraries
# ---

# %%
import pandas as pd
import numpy as np 
from scipy import sparse
import pickle

from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity

# %% [markdown]
# ## Import Dataset
# ---

# %%
df = pd.read_csv('../data/clusters_bat.csv').drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#     MLBID FIRSTNAME  LASTNAME          Player Team Pos  Age    G   AB   R  \
# 0  547989      Jose     Abreu      Jose Abreu  CWS  1B   34  152  566  86
# 1  642715     Willy    Adames    Willy Adames   TB  SS   26   41  132  16
# 2  501303     Ehire  Adrianza  Ehire Adrianza  ATL  SS   32  109  182  32
# 3  542583     Jesus   Aguilar   Jesus Aguilar  MIA  1B   31  131  449  49
# 4  605113      Nick     Ahmed      Nick Ahmed  ARI  SS   31  129  434  46
#
#    ...  HR  RBI  BB   SO    AVG    OBP    SLG    OPS    salary  cluster
# 0  ...  30  117  61  143  0.261  0.351  0.481  0.832  17666666        0
# 1  ...   5   15  10   51  0.197  0.254  0.371  0.625    590000        4
# 2  ...   5   28  21   42  0.247  0.327  0.401  0.728   1500000        5
# 3  ...  22   93  46   93  0.261  0.329  0.459  0.788   4500000        3
# 4  ...   5   38  34  104  0.221  0.280  0.339  0.619   8125000        2
#
# [5 rows x 23 columns]

# %%
df.drop(columns = ['MLBID', 'FIRSTNAME', 'LASTNAME', 'Team', 'Pos', 'Age', 'G'], inplace = True)
df.head()
# Out:
#            Player   AB   R    H  2B  3B  HR  RBI  BB   SO    AVG    OBP  \
# 0      Jose Abreu  566  86  148  30   2  30  117  61  143  0.261  0.351
# 1    Willy Adames  132  16   26   6   1   5   15  10   51  0.197  0.254
# 2  Ehire Adrianza  182  32   45   9   2   5   28  21   42  0.247  0.327
# 3   Jesus Aguilar  449  49  117  23   0  22   93  46   93  0.261  0.329
# 4      Nick Ahmed  434  46   96  30   3   5   38  34  104  0.221  0.280
#
#      SLG    OPS    salary  cluster
# 0  0.481  0.832  17666666        0
# 1  0.371  0.625    590000        4
# 2  0.401  0.728   1500000        5
# 3  0.459  0.788   4500000        3
# 4  0.339  0.619   8125000        2

# %% [markdown]
# ## Create Pivot Table
# ---

# %%
pivot = pd.pivot_table(df, index = 'Player')
pivot.head()
# Out:
#                    2B  3B   AB    AVG  BB    H  HR    OBP    OPS   R  RBI  \
# Player
# Aaron Hicks         3   0  108  0.194  14   21   4  0.294  0.627  13   14
# Aaron Judge        24   0  550  0.287  75  158  39  0.373  0.917  89   98
# Adalberto Mondesi   8   1  126  0.230   6   29   6  0.271  0.723  19   17
# Adam Duvall         7   1  199  0.226  14   45  16  0.287  0.800  26   45
# Adam Engel          9   0  123  0.252  11   31   7  0.336  0.832  21   18
#
#                      SLG   SO  cluster    salary
# Player
# Aaron Hicks        0.333   30        4  10785714
# Aaron Judge        0.544  158        0  10175000
# Adalberto Mondesi  0.452   43        5   2525000
# Adam Duvall        0.513   69        5   2000000
# Adam Engel         0.496   31        5   1375000

# %%
sparse_pivot = sparse.csr_matrix(pivot.fillna(0))

# %%
recommender = cosine_distances(sparse_pivot)

# %%
recommender_df = pd.DataFrame(recommender, columns=pivot.index, index=pivot.index)
recommender_df.head()
# Out:
# Player              Aaron Hicks   Aaron Judge  Adalberto Mondesi  \
# Player
# Aaron Hicks        0.000000e+00  1.233091e-09       9.854307e-10
# Aaron Judge        1.233091e-09  0.000000e+00       3.880596e-11
# Adalberto Mondesi  9.854307e-10  3.880596e-11       0.000000e+00
# Adam Duvall        5.065540e-09  1.341507e-09       1.609302e-09
# Adam Engel         3.790208e-09  7.196937e-10       9.355794e-10
#
# Player              Adam Duvall    Adam Engel  Adam Frazier  Adolis Garcia  \
# Player
# Aaron Hicks        5.065540e-09  3.790208e-09  6.588102e-10   6.107854e-07
# Aaron Judge        1.341507e-09  7.196937e-10  1.510383e-10   5.574884e-07
# Adalberto Mondesi  1.609302e-09  9.355794e-10  9.722134e-11   5.627906e-07
# Adam Duvall        0.000000e+00  1.789338e-10  2.263531e-09   5.049810e-07
# Adam Engel         1.789338e-10  0.000000e+00  1.357678e-09   5.188637e-07
#
# Player              Akil Baddoo  Albert Pujols  Alcides Escobar  ...  \
# Player                                                           ...
# Aaron Hicks        3.082166e-07   1.085759e-08     1.745031e-07  ...
# Aaron Judge        2.706011e-07   4.935004e-09     1.468132e-07  ...
# Adalberto Mondesi  2.745317e-07   5.448153e-09     1.497017e-07  ...
# Adam Duvall        2.349014e-07   1.431801e-09     1.216820e-07  ...
# Adam Engel         2.438529e-07   1.974077e-09     1.271686e-07  ...
#
# Player             Yadiel Hernandez  Yadier Molina     Yan Gomes  \
# Player
# Aaron Hicks            1.184278e-07   8.559761e-10  8.024170e-11
# Aaron Judge            9.565294e-08   6.541701e-11  6.950838e-10
# Adalberto Mondesi      9.803472e-08   4.121403e-11  5.097190e-10
# Adam Duvall            7.519161e-08   1.846381e-09  3.893640e-09
# Adam Engel             7.998225e-08   1.076636e-09  2.775526e-09
#
# Player               Yandy Diaz  Yasmani Grandal  Yoan Moncada  Yonathan Daza  \
# Player
# Aaron Hicks        3.526380e-07     2.771883e-11  2.729360e-09   1.521084e-07
# Aaron Judge        3.124879e-07     9.253741e-10  3.101950e-10   1.263120e-07
# Adalberto Mondesi  3.170856e-07     7.317278e-10  4.694561e-10   1.289939e-07
# Adam Duvall        2.748865e-07     4.435886e-09  4.619628e-10   1.028562e-07
# Adam Engel         2.837393e-07     3.247767e-09  1.262529e-10   1.082578e-07
#
# Player             Yonny Hernandez  Yordan Alvarez  Zack Collins
# Player
# Aaron Hicks           3.257034e-08    4.690657e-07  6.727126e-08
# Aaron Judge           2.136114e-08    4.222711e-07  5.047139e-08
# Adalberto Mondesi     2.242355e-08    4.273817e-07  5.213752e-08
# Adam Duvall           1.264069e-08    3.772508e-07  3.584162e-08
# Adam Engel            1.438409e-08    3.886910e-07  3.947122e-08
#
# [5 rows x 393 columns]

# %% [markdown]
# ## Test Recommender
# ---

# %%
recommender_df['Mookie Betts'].sort_values()[1:11]
# Out:
# Player
# Jose Altuve         6.240564e-13
# Francisco Lindor    1.205924e-12
# Josh Donaldson      2.583156e-12
# Starling Marte      2.909673e-12
# Kole Calhoun        4.128475e-12
# Kyle Schwarber      4.495515e-12
# Yan Gomes           4.724887e-12
# Brandon Belt        4.825473e-12
# Buster Posey        5.035528e-12
# Wil Myers           5.295875e-12
# Name: Mookie Betts, dtype: float64

# %% [markdown]
# ## Save CSV and Pickle Files of Recommendation
# ---

# %%
recommender_df.to_csv('../data/recommender_bat.csv', index = False)

# %%
with open('../pickles/recommendation_bat.pkl', 'wb') as pickle_out:
    pickle_out = pickle.dump(recommender_df, pickle_out)

# %% [markdown]
# ## Recap
# ---
# Create a recommendation system from current stats, salaries and clusters for each batter. This will be used in the app
