# %% [markdown]
# # Batter K-Means Clustering
# ---
# This notebook aims to use current stats and salary of batters for K-Means Clustering.

# %% [markdown]
# ## Import Libraries
# ---

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Dataset
# ---

# %%
df = pd.read_csv('../data/mlb_players_bat.csv').drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#     MLBID FIRSTNAME  LASTNAME          Player Team Pos  Age    G   AB   R  \
# 0  547989      Jose     Abreu      Jose Abreu  CWS  1B   34  152  566  86
# 1  642715     Willy    Adames    Willy Adames   TB  SS   26   41  132  16
# 2  501303     Ehire  Adrianza  Ehire Adrianza  ATL  SS   32  109  182  32
# 3  542583     Jesus   Aguilar   Jesus Aguilar  MIA  1B   31  131  449  49
# 4  605113      Nick     Ahmed      Nick Ahmed  ARI  SS   31  129  434  46
#
#    ...  3B  HR  RBI  BB   SO    AVG    OBP    SLG    OPS       salary
# 0  ...   2  30  117  61  143  0.261  0.351  0.481  0.832  $17,666,666
# 1  ...   1   5   15  10   51  0.197  0.254  0.371  0.625     $590,000
# 2  ...   2   5   28  21   42  0.247  0.327  0.401  0.728   $1,500,000
# 3  ...   0  22   93  46   93  0.261  0.329  0.459  0.788   $4,500,000
# 4  ...   3   5   38  34  104  0.221  0.280  0.339  0.619   $8,125,000
#
# [5 rows x 22 columns]

# %%
# Convert salary from object to int
df['salary'] = df['salary'].str.replace(',', '').str.replace('$', '').astype(int)

#Copied from https://stackoverflow.com/questions/38516481/trying-to-remove-commas-and-dollars-signs-with-pandas-in-python
# Out:
# <ipython-input-3-3820715aeb76>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['salary'] = df['salary'].str.replace(',', '').str.replace('$', '').astype(int)

# %%
df_copy = df.drop(columns = ['MLBID', 'FIRSTNAME', 'LASTNAME', 'Player', 'Team', 'Pos', 'G', 'Age'])

# %% [markdown]
# ## Preprocessing
# ---
# ### Standard Scaler

# %%
sc = StandardScaler()
X_sc = sc.fit_transform(df_copy)

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components = 5)
pca.fit(X_sc)
X_pca = pca.transform(X_sc)

# %% [markdown]
# ## Model
# ---

# %%
km = KMeans(n_clusters = 6, random_state=42)
km.fit(X_pca)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %%
df['cluster'] = km.labels_
df.head()
# Out:
#     MLBID FIRSTNAME  LASTNAME          Player Team Pos  Age    G   AB   R  \
# 0  547989      Jose     Abreu      Jose Abreu  CWS  1B   34  152  566  86
# 1  642715     Willy    Adames    Willy Adames   TB  SS   26   41  132  16
# 2  501303     Ehire  Adrianza  Ehire Adrianza  ATL  SS   32  109  182  32
# 3  542583     Jesus   Aguilar   Jesus Aguilar  MIA  1B   31  131  449  49
# 4  605113      Nick     Ahmed      Nick Ahmed  ARI  SS   31  129  434  46
#
#    ...  HR  RBI  BB   SO    AVG    OBP    SLG    OPS    salary  cluster
# 0  ...  30  117  61  143  0.261  0.351  0.481  0.832  17666666        0
# 1  ...   5   15  10   51  0.197  0.254  0.371  0.625    590000        4
# 2  ...   5   28  21   42  0.247  0.327  0.401  0.728   1500000        5
# 3  ...  22   93  46   93  0.261  0.329  0.459  0.788   4500000        3
# 4  ...   5   38  34  104  0.221  0.280  0.339  0.619   8125000        2
#
# [5 rows x 23 columns]

# %%
df.groupby('cluster').mean()
# Out:
#                  MLBID        Age           G          AB          R  \
# cluster
# 0        588428.224490  29.102041  146.081633  536.918367  89.877551
# 1        594071.000000  29.214286   76.178571  252.571429  43.964286
# 2        600327.074074  28.629630  110.246914  341.271605  42.271605
# 3        600517.684932  28.561644  139.410959  497.410959  71.068493
# 4        601945.383562  28.630137   56.917808  152.383562  16.205479
# 5        600385.752809  28.516854   65.910112  187.056180  24.179775
#
#                   H         2B        3B         HR        RBI         BB  \
# cluster
# 0        147.285714  30.142857  1.530612  31.551020  92.734694  62.020408
# 1         73.428571  15.392857  1.071429  12.321429  37.678571  33.642857
# 2         79.555556  15.493827  1.271605  11.271605  42.777778  31.938272
# 3        127.671233  26.082192  2.835616  17.123288  64.739726  48.301370
# 4         30.232877   5.739726  0.424658   3.876712  14.616438  12.164384
# 5         47.516854   9.382022  0.988764   5.685393  22.932584  17.000000
#
#                  SO       AVG       OBP       SLG       OPS        salary
# cluster
# 0        128.346939  0.273959  0.354061  0.513000  0.867061  1.139448e+07
# 1         59.250000  0.293429  0.381786  0.511964  0.893750  8.757903e+06
# 2         91.074074  0.231667  0.304605  0.388407  0.693012  3.054138e+06
# 3        117.808219  0.256041  0.327945  0.425219  0.753164  5.820815e+06
# 4         43.410959  0.195616  0.263849  0.314466  0.578315  2.207520e+06
# 5         44.651685  0.252315  0.322562  0.408978  0.731539  2.444367e+06

# %%
df.columns
# Out:
# Index(['MLBID', 'FIRSTNAME', 'LASTNAME', 'Player', 'Team', 'Pos', 'Age', 'G',
#        'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'AVG', 'OBP',
#        'SLG', 'OPS', 'salary', 'cluster'],
#       dtype='object')

# %%
silhouette_score(X_pca, km.labels_)
# Out:
# 0.22484264960836448

# %%
df['cluster'].value_counts(normalize = True)
# Out:
# 5    0.226463
# 2    0.206107
# 3    0.185751
# 4    0.185751
# 0    0.124682
# 1    0.071247
# Name: cluster, dtype: float64

# %% [markdown]
# ## Save Dataset with Clusters
# ---

# %%
df.to_csv('../data/clusters_bat.csv')

# %% [markdown]
# ## Recap
# ---
# K-Means Clustering was used on the dataset with current stats and salary of batters. This dataset will be used for the recommender system.
