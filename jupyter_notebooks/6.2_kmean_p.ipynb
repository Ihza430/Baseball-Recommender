# %% [markdown]
# # Pitcher K-Means Clustering
# ---
# This notebook aims to use current stats and salary of pitchers for K-Means Clustering.

# %% [markdown]
# ## Import Libraries
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Dataset
# ---

# %%
df = pd.read_csv('../data/mlb_players_pitch.csv').drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#     MLBID FIRSTNAME LASTNAME           Player Team  Age  W   L   ERA    IP  \
# 0  472551  Fernando     Abad    Fernando Abad  BAL   35  0   0  5.60  17.2
# 1  676265      Cory   Abbott      Cory Abbott  CHC   26  0   0  6.75  17.1
# 2  642758   Domingo  Acevedo  Domingo Acevedo  OAK   27  0   0  3.27  11.0
# 3  613534    Austin    Adams     Austin Adams   SD   30  3   2  4.10  52.2
# 4  669211    Keegan     Akin      Keegan Akin  BAL   26  2  10  6.63  95.0
#
#      H  ER  HR  BB   K  WHIP    salary
# 0   23  11   1   7  10  1.70  $570,500
# 1   20  13   7  11  12  1.79  $570,500
# 2    9   4   3   4   9  1.18  $570,500
# 3   28  24   1  35  76  1.20  $580,200
# 4  110  70  17  40  82  1.58  $570,500

# %%
# Convert salary from object to int
df['salary'] = df['salary'].str.replace(',', '').str.replace('$', '').astype(int)

#Copied from https://stackoverflow.com/questions/38516481/trying-to-remove-commas-and-dollars-signs-with-pandas-in-python
# Out:
# <ipython-input-3-3820715aeb76>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['salary'] = df['salary'].str.replace(',', '').str.replace('$', '').astype(int)

# %%
df_copy = df.drop(columns = ['MLBID', 'FIRSTNAME', 'LASTNAME', 'Player', 'Team', 'Age'])

# %% [markdown]
# ## Preprocessing
# ---
# ### Standard Scaler

# %%
sc = StandardScaler()
X_sc = sc.fit_transform(df_copy)

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components = 5)
pca.fit(X_sc)
X_pca = pca.transform(X_sc)

# %% [markdown]
# ## Model
# ---

# %%
km = KMeans(n_clusters = 6, random_state=42)
km.fit(X_pca)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %%
df['cluster'] = km.labels_
df.head()
# Out:
#     MLBID FIRSTNAME LASTNAME           Player Team  Age  W   L   ERA    IP  \
# 0  472551  Fernando     Abad    Fernando Abad  BAL   35  0   0  5.60  17.2
# 1  676265      Cory   Abbott      Cory Abbott  CHC   26  0   0  6.75  17.1
# 2  642758   Domingo  Acevedo  Domingo Acevedo  OAK   27  0   0  3.27  11.0
# 3  613534    Austin    Adams     Austin Adams   SD   30  3   2  4.10  52.2
# 4  669211    Keegan     Akin      Keegan Akin  BAL   26  2  10  6.63  95.0
#
#      H  ER  HR  BB   K  WHIP  salary  cluster
# 0   23  11   1   7  10  1.70  570500        2
# 1   20  13   7  11  12  1.79  570500        2
# 2    9   4   3   4   9  1.18  570500        4
# 3   28  24   1  35  76  1.20  580200        3
# 4  110  70  17  40  82  1.58  570500        1

# %%
df.groupby('cluster').mean()
# Out:
#                  MLBID        Age          W         L       ERA          IP  \
# cluster
# 0        511034.642857  33.428571   5.857143  3.357143  3.118571   73.835714
# 1        616556.603175  27.666667   6.349206  7.984127  4.613810  120.355556
# 2        604453.774194  28.596774   1.516129  2.419355  6.119677   33.958065
# 3        596382.838983  29.372881   4.542373  3.754237  3.492966   68.038983
# 4        579891.294118  30.529412   1.519608  1.245098  3.083824   28.309804
# 5        579516.117647  29.666667  11.254902  8.470588  3.755882  169.476471
#
#                   H         ER         HR         BB           K      WHIP  \
# cluster
# 0         59.000000  25.071429   8.500000  21.857143   88.214286  1.119286
# 1        118.968254  61.063492  17.873016  40.269841  108.634921  1.328254
# 2         37.532258  23.096774   5.903226  16.387097   32.790323  1.585645
# 3         56.737288  26.220339   8.228814  25.423729   72.737288  1.213729
# 4         22.431373   9.352941   2.872549   9.647059   29.019608  1.149804
# 5        150.372549  70.254902  21.882353  49.647059  175.862745  1.183529
#
#                salary
# cluster
# 0        2.476572e+07
# 1        2.268407e+06
# 2        1.440671e+06
# 3        2.137334e+06
# 4        1.703257e+06
# 5        9.360466e+06

# %%
df.columns
# Out:
# Index(['MLBID', 'FIRSTNAME', 'LASTNAME', 'Player', 'Team', 'Age', 'W', 'L',
#        'ERA', 'IP', 'H', 'ER', 'HR', 'BB', 'K', 'WHIP', 'salary', 'cluster'],
#       dtype='object')

# %%
silhouette_score(X_pca, km.labels_)
# Out:
# 0.2757783945908426

# %%
df['cluster'].value_counts(normalize = True)
# Out:
# 3    0.287805
# 4    0.248780
# 1    0.153659
# 2    0.151220
# 5    0.124390
# 0    0.034146
# Name: cluster, dtype: float64

# %% [markdown]
# ## Save Dataset with Clusters
# ---

# %%
df.to_csv('../data/clusters_pitch.csv')

# %% [markdown]
# ## Recap
# ---
# K-Means Clustering was used on the dataset with current stats and salary of pitchers. This dataset will be used for the recommender system.
