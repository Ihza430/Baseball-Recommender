# %% [markdown]
# # Active Players Cleaning
# ---

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/mlb_players.csv').drop(['Unnamed: 0'], axis = 1)

# %%
df.head()
# Out:
#     MLBID FIRSTNAME  LASTNAME ACTIVE          Player Team Pos  Age    G   AB  \
# 0  547989      Jose     Abreu      Y      Jose Abreu  CWS  1B   34  152  566
# 1  642715     Willy    Adames      Y    Willy Adames   TB  SS   26   41  132
# 2  501303     Ehire  Adrianza      Y  Ehire Adrianza  ATL  SS   32  109  182
# 3  542583     Jesus   Aguilar      Y   Jesus Aguilar  MIA  1B   31  131  449
# 4  605113      Nick     Ahmed      Y      Nick Ahmed  ARI  SS   31  129  434
#
#     R    H  2B  3B  HR  RBI  SB  CS  BB   SO  SH  SF  HBP    AVG    OBP  \
# 0  86  148  30   2  30  117   1   0  61  143   0  10   22  0.261  0.351
# 1  16   26   6   1   5   15   1   2  10   51   0   0    0  0.197  0.254
# 2  32   45   9   2   5   28   0   0  21   42   1   3    2  0.247  0.327
# 3  49  117  23   0  22   93   0   0  46   93   0   7    3  0.261  0.329
# 4  46   96  30   3   5   38   7   2  34  104   2   1    2  0.221  0.280
#
#      SLG    OPS       salary
# 0  0.481  0.832  $17,666,666
# ...

# %%
df = df.drop(columns = ['SB', 'HBP', 'SH', 'SF', 'CS'])
df.head()
# Out:
#     MLBID FIRSTNAME  LASTNAME ACTIVE          Player Team Pos  Age    G   AB  \
# 0  547989      Jose     Abreu      Y      Jose Abreu  CWS  1B   34  152  566
# 1  642715     Willy    Adames      Y    Willy Adames   TB  SS   26   41  132
# 2  501303     Ehire  Adrianza      Y  Ehire Adrianza  ATL  SS   32  109  182
# 3  542583     Jesus   Aguilar      Y   Jesus Aguilar  MIA  1B   31  131  449
# 4  605113      Nick     Ahmed      Y      Nick Ahmed  ARI  SS   31  129  434
#
#     R    H  2B  3B  HR  RBI  BB   SO    AVG    OBP    SLG    OPS       salary
# 0  86  148  30   2  30  117  61  143  0.261  0.351  0.481  0.832  $17,666,666
# 1  16   26   6   1   5   15  10   51  0.197  0.254  0.371  0.625     $590,000
# 2  32   45   9   2   5   28  21   42  0.247  0.327  0.401  0.728   $1,500,000
# 3  49  117  23   0  22   93  46   93  0.261  0.329  0.459  0.788   $4,500,000
# 4  46   96  30   3   5   38  34  104  0.221  0.280  0.339  0.619   $8,125,000

# %%
df.isnull().sum()
# Out:
# MLBID        0
# FIRSTNAME    0
# LASTNAME     0
# ACTIVE       0
# Player       0
# Team         0
# Pos          0
# Age          0
# G            0
# AB           0
# R            0
# H            0
# 2B           0
# 3B           0
# HR           0
# RBI          0
# BB           0
# SO           0
# AVG          0
# OBP          0
# SLG          0
# OPS          0
# salary       0
# dtype: int64

# %%
df.to_csv('../data/mlb_players.csv')
