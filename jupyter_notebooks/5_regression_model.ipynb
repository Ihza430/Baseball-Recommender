# %% [markdown]
# # Predicting Salary Using Regression Model
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.ensemble import AdaBoostRegressor, VotingRegressor

import pickle

# %%
df = pd.read_csv('../data/past_salaries.csv').drop(['Unnamed: 0'], axis = 1)
df.head()
# Out:
#     playerID  yearID teamID_x lgID_x    G   AB   R    H  2B  3B  ...  BB  \
# 0  abreujo02    2016      CHA     AL  159  624  67  183  32   1  ...  47
# 1  ackledu01    2016      NYA     AL   28   61   6    9   0   0  ...   8
# 2  adamecr01    2016      COL     NL  121  225  25   49   7   3  ...  24
# 3  adamsma01    2016      SLN     NL  118  297  37   74  18   0  ...  25
# 4  adriaeh01    2016      SFN     NL   40   63   3   16   2   0  ...   2
#
#       SO   HBP   SH   SF    AVG    OBP    SLG    OPS    salary
# 0  125.0  15.0  0.0  9.0  0.293  0.353  0.468  0.821  11666667
# 1    9.0   0.0  0.0  1.0  0.148  0.243  0.148  0.391   3200000
# 2   47.0   4.0  3.0  0.0  0.218  0.304  0.302  0.606    509500
# 3   81.0   2.0  0.0  3.0  0.249  0.309  0.471  0.780   1650000
# 4   13.0   2.0  4.0  0.0  0.254  0.299  0.381  0.680    512500
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (424, 24)

# %% [markdown]
# ## Create X and y variables for Salary

# %%
X = df.drop(columns = ['playerID', 'salary', 'teamID_x', 'lgID_x', 'yearID', 'G'])
y = df['salary']
X.head()
# Out:
#     AB   R    H  2B  3B  HR    RBI   SB   CS  BB     SO   HBP   SH   SF  \
# 0  624  67  183  32   1  25  100.0  0.0  2.0  47  125.0  15.0  0.0  9.0
# 1   61   6    9   0   0   0    4.0  0.0  0.0   8    9.0   0.0  0.0  1.0
# 2  225  25   49   7   3   2   17.0  2.0  3.0  24   47.0   4.0  3.0  0.0
# 3  297  37   74  18   0  16   54.0  0.0  1.0  25   81.0   2.0  0.0  3.0
# 4   63   3   16   2   0   2    7.0  0.0  1.0   2   13.0   2.0  4.0  0.0
#
#      AVG    OBP    SLG    OPS
# 0  0.293  0.353  0.468  0.821
# 1  0.148  0.243  0.148  0.391
# 2  0.218  0.304  0.302  0.606
# 3  0.249  0.309  0.471  0.780
# 4  0.254  0.299  0.381  0.680

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.3, random_state=42)

# %% [markdown]
# ## Standard Scaler

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
pca = PCA(random_state=42)
X_train_p = pca.fit_transform(X_train_sc)
X_test_p = pca.transform(X_test_sc)

# %%
def reg_metrics(x, y, model):
    y_pred = model.predict(x)
    resids = y - y_pred

    mse = metrics.mean_squared_error(y, y_pred)
    rmse = metrics.mean_squared_error(y, y_pred, squared = False)
    score = model.score(x, y)
    
    print(model)
    print("R2: ", score)
    print("MSE: ", mse)
    print("RMSE: ", rmse)

# %%
def fit_models(x, y, x_test, y_test, model):
    model.fit(x, y)
    
    print()
    print(f'Train')
    reg_metrics(x, y, model)
    
    print()
    print(f'Test')
    reg_metrics(x_test, y_test, model)

# %% [markdown]
# ## Voting Model

# %%
l_alphas = np.logspace(-3, 1, 100)
e_alphas = np.linspace(0.01, 1, 100)
enet_ratio = 0.05
r_alphas = np.logspace(0, 5, 220)

# %%
vote = VotingRegressor([
    ('ad', AdaBoostRegressor(random_state=42)),
    ('rid', RidgeCV(r_alphas, scoring='r2', cv=5)),
    ('las', LassoCV(alphas=l_alphas, cv=5, max_iter=50_000, n_jobs=-1)),
    ('enet_model', ElasticNetCV(alphas=e_alphas, l1_ratio=enet_ratio, cv=5, max_iter=3000, n_jobs=-1))
])

# %%
fit_models(X_train_p, y_train, X_test_p, y_test, vote)
# Out:
# Train
# VotingRegressor(estimators=[('ad', AdaBoostRegressor(random_state=42)),
#                             ('rid',
#                              RidgeCV(alphas=array([1.00000000e+00, 1.05397680e+00, 1.11086709e+00, 1.17082814e+00,
#        1.23402569e+00, 1.30063444e+00, 1.37083853e+00, 1.44483200e+00,
#        1.52281940e+00, 1.60501632e+00, 1.69164996e+00, 1.78295980e+00,
#        1.87919826e+00, 1.98063137e+00, 2.08753951e+00, 2.20021820e+00,
#        2.31897894e...
#        0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41, 0.42, 0.43, 0.44,
#        0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52, 0.53, 0.54, 0.55,
#        0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63, 0.64, 0.65, 0.66,
#        0.67, 0.68, 0.69, 0.7 , 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77,
#        0.78, 0.79, 0.8 , 0.81, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88,
#        0.89, 0.9 , 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99,
#        1.  ]),
#                                           cv=5, l1_ratio=0.05, max_iter=3000,
#                                           n_jobs=-1))])
# R2:  0.43653129960328196
# MSE:  28242581228892.645
# RMSE:  5314374.961262392
#
# Test
# VotingRegressor(estimators=[('ad', AdaBoostRegressor(random_state=42)),
#                             ('rid',
#                              RidgeCV(alphas=array([1.00000000e+00, 1.05397680e+00, 1.11086709e+00, 1.17082814e+00,
#        1.23402569e+00, 1.30063444e+00, 1.37083853e+00, 1.44483200e+00,
#        1.52281940e+00, 1.60501632e+00, 1.69164996e+00, 1.78295980e+00,
#        1.87919826e+00, 1.98063137e+00, 2.08753951e+00, 2.20021820e+00,
#        2.31897894e...
#        0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41, 0.42, 0.43, 0.44,
#        0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52, 0.53, 0.54, 0.55,
#        0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63, 0.64, 0.65, 0.66,
#        0.67, 0.68, 0.69, 0.7 , 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77,
#        0.78, 0.79, 0.8 , 0.81, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88,
#        0.89, 0.9 , 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99,
#        1.  ]),
#                                           cv=5, l1_ratio=0.05, max_iter=3000,
#                                           n_jobs=-1))])
# R2:  0.12917983914058362
# MSE:  33430897138438.26
# RMSE:  5781945.791724293

# %%
with open('../model/salary_model.pkl', 'wb') as pickle_out:
    pickle_out = pickle.dump(vote, pickle_out)
